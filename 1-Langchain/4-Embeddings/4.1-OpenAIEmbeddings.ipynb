# %%
from langchain_openai import OpenAIEmbeddings ##there are some charges applied when we do openAI Embeddings

embedding = OpenAIEmbeddings(model="text-embedding-3-large")
embedding

# %%
len(embedding)

# %%
text = "this is a tutorial on OpenAI Embedding"
query_result = embedding = embed_query(text)
query_result

# %%
len(embedding)##by default 3072 dimension

# %%
embedding_1024 = OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024) ##manually setting up the dimensions

# %%
query_result = embedding_1024.embed_query(text)
len(query_result) ##1024

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
docs = loader.load()
docs

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_docs = text_splitter.split_documents(docs)
final_docs

# %%
##Vector Embedding and Vector StoreDB

from langchain_community.vectorstores import Chroma

db = Chroma.from_documents(final_docs,embedding=embedding_1024)
db

# %%
## take one text line from speech.txt

query = "It will be all the easier for us to conduct ourselves as belligerents"
retrieved_result = db.similarity_search(query)
print(retrieved_result)
